# %%
import sys
print("Python:", sys.version)
# Out:
# Python: 3.12.9 (tags/v3.12.9:fdb8142, Feb  4 2025, 15:27:58) [MSC v.1942 64 bit (AMD64)]

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import jupyter_core

print("PyTorch:", torch.__version__)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Jupyter Core:", jupyter_core.__version__)
# Out:
# PyTorch: 2.12.0+cpu
# NumPy: 2.4.6
# Pandas: 3.0.3
# Matplotlib: 3.10.9
# Scikit-learn: 1.9.0
# Jupyter Core: 5.9.1

# %%
import torch

tensor = torch.tensor([1.0, 2.0, 3.0])
print("Tensor:", tensor)
print("Dispositivo:", tensor.device)
print("PyTorch operacional:", torch.add(tensor, tensor))
# Out:
# Tensor: tensor([1., 2., 3.])
# Dispositivo: cpu
# PyTorch operacional: tensor([2., 4., 6.])
